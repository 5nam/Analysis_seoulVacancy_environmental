# %%
import pandas as pd

# %%
emp = pd.read_csv('../data/raw/최종_서울시_빈집_현황.csv')
air = pd.read_csv('../data/raw/최종_대기환경정보.csv')

# %%
emp.head()
# Out:
#    year   gu    소계  단독주택   아파트  연립주택  다세대주택  비거주용_건물내_주택
# 0  2020  종로구  2194   330   566   310    896           92
# 1  2020   중구  1850    53  1157    99    458           83
# 2  2020  용산구  4513   217  2569   445   1197           85
# 3  2020  성동구  2538   473  1170    63    783           49
# 4  2020  광진구   735     0   360    57    292           22

# %%
air.head()
# Out:
#    year   gu  이산화질소농도(ppm)  오존농도(ppm)  일산화탄소농도(ppm)  아황산가스농도(ppm)  \
# 0  2020  강남구         0.037      0.003           0.7         0.003
# 1  2020  강동구         0.036      0.004           0.6         0.003
# 2  2020  강북구         0.045      0.004           0.7         0.003
# 3  2020  강서구         0.041      0.004           0.6         0.005
# 4  2020  관악구         0.043      0.008           0.7         0.003
#
#    미세먼지농도(㎍/㎥)  초미세먼지농도(㎍/㎥)
# 0         31.0          23.0
# 1         37.0          28.0
# 2         41.0          27.0
# 3         39.0          23.0
# 4         35.0          22.0

# %%
noise = pd.read_csv('../data/전체_연도별_구별_소음_데이터.csv')
noise
# Out:
#     year   gu  소음_소계
# 0   2020  종로구   2016
# 1   2020   중구   1060
# 2   2020  용산구   1625
# 3   2020  성동구   1860
# 4   2020  광진구   1943
# ..   ...  ...    ...
# 70  2022  관악구   3531
# 71  2022  서초구   5252
# 72  2022  강남구   9883
# 73  2022  송파구   3327
# 74  2022  강동구   3750
#
# [75 rows x 3 columns]

# %%
pollute = pd.read_csv('../data/전체_연도별_구별_환경오염물질_배출시설.csv')
pollute
# Out:
#     year   gu  대기_소계  수질_소계
# 0   2020  강남구    186    182
# 1   2020  강동구     26    107
# 2   2020  강북구     20     56
# 3   2020  강서구    143    199
# 4   2020  관악구     29     52
# ..   ...  ...    ...    ...
# 70  2022  용산구     63     53
# 71  2022  은평구     22     61
# 72  2022  종로구    134    204
# 73  2022   중구    244    290
# 74  2022  중랑구     29     67
#
# [75 rows x 4 columns]

# %%
emp.rename(columns={'소계':'빈집_소계'}, inplace=True)

# %%
data = pd.merge(emp, on=['gu','year'], right=air)

# %%
data.head()
# Out:
#    year   gu  빈집_소계  단독주택  아파트  연립주택  다세대주택  비거주용_건물내_주택  이산화질소농도(ppm)  \
# 0  2020  종로구   2194   330  566   310    896           92         0.041
# 1  2020  종로구   2194   330  566   310    896           92         0.045
# 2  2020  종로구   2194   330  566   310    896           92         0.038
# 3  2020  종로구   2194   330  566   310    896           92         0.042
# 4  2020  종로구   2194   330  566   310    896           92         0.050
#
#    오존농도(ppm)  일산화탄소농도(ppm)  아황산가스농도(ppm)  미세먼지농도(㎍/㎥)  초미세먼지농도(㎍/㎥)
# 0      0.003           0.7         0.003         35.0          25.0
# 1      0.002           0.9         0.004         49.0          37.0
# 2      0.010           0.9         0.004         66.0          48.0
# 3      0.013           1.0         0.005         55.0          41.0
# 4      0.007           1.0         0.005         54.0          40.0

# %%
data = pd.merge(emp, on=['gu','year'], right=air)
data
# Out:
#        year   gu  빈집_소계  단독주택   아파트  연립주택  다세대주택  비거주용_건물내_주택  이산화질소농도(ppm)  \
# 0      2020  종로구   2194   330   566   310    896           92         0.041
# 1      2020  종로구   2194   330   566   310    896           92         0.045
# 2      2020  종로구   2194   330   566   310    896           92         0.038
# 3      2020  종로구   2194   330   566   310    896           92         0.042
# 4      2020  종로구   2194   330   566   310    896           92         0.050
# ...     ...  ...    ...   ...   ...   ...    ...          ...           ...
# 27395  2022  강동구   5183     6  3324   176   1635           42         0.040
# 27396  2022  강동구   5183     6  3324   176   1635           42         0.026
# 27397  2022  강동구   5183     6  3324   176   1635           42         0.031
# 27398  2022  강동구   5183     6  3324   176   1635           42         0.030
# 27399  2022  강동구   5183     6  3324   176   1635           42         0.039
#
# ...

# %%
data = pd.merge(data, on=['gu','year'], right=noise)
data
# Out:
#        year   gu  빈집_소계  단독주택   아파트  연립주택  다세대주택  비거주용_건물내_주택  이산화질소농도(ppm)  \
# 0      2020  종로구   2194   330   566   310    896           92         0.041
# 1      2020  종로구   2194   330   566   310    896           92         0.045
# 2      2020  종로구   2194   330   566   310    896           92         0.038
# 3      2020  종로구   2194   330   566   310    896           92         0.042
# 4      2020  종로구   2194   330   566   310    896           92         0.050
# ...     ...  ...    ...   ...   ...   ...    ...          ...           ...
# 27395  2022  강동구   5183     6  3324   176   1635           42         0.040
# 27396  2022  강동구   5183     6  3324   176   1635           42         0.026
# 27397  2022  강동구   5183     6  3324   176   1635           42         0.031
# 27398  2022  강동구   5183     6  3324   176   1635           42         0.030
# 27399  2022  강동구   5183     6  3324   176   1635           42         0.039
#
# ...

# %%
data = pd.merge(data, on=['gu','year'], right=pollute)
data
# Out:
#        year   gu  빈집_소계  단독주택   아파트  연립주택  다세대주택  비거주용_건물내_주택  이산화질소농도(ppm)  \
# 0      2020  종로구   2194   330   566   310    896           92         0.041
# 1      2020  종로구   2194   330   566   310    896           92         0.045
# 2      2020  종로구   2194   330   566   310    896           92         0.038
# 3      2020  종로구   2194   330   566   310    896           92         0.042
# 4      2020  종로구   2194   330   566   310    896           92         0.050
# ...     ...  ...    ...   ...   ...   ...    ...          ...           ...
# 27395  2022  강동구   5183     6  3324   176   1635           42         0.040
# 27396  2022  강동구   5183     6  3324   176   1635           42         0.026
# 27397  2022  강동구   5183     6  3324   176   1635           42         0.031
# 27398  2022  강동구   5183     6  3324   176   1635           42         0.030
# 27399  2022  강동구   5183     6  3324   176   1635           42         0.039
#
# ...

# %%
data.to_csv('../data/전체_데이터_합본_년도별.csv', index=False)
